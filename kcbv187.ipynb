# %% [markdown]
# <a href="https://colab.research.google.com/github/ferryajp/KCBVbaru/blob/main/kcbv187.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tipe data Boolean
print(True)

#tipe data String
print("Ayo belajar Python")
print('Belajar Python Sangat Mudah')

#tipe data Integer
print(20)

#tipe data Float
print(3.14)

#tipe data Complex
print(5j)

#tipe data List
print([1,2,3,4,5])
print(["satu", "dua", "tiga"])

#tipe data Tuple
print((1,2,3,4,5))
print(("satu", "dua", "tiga"))

#tipe data Dictionary
print({"nama":"Budi", 'umur':20})
#tipe data Dictionary dimasukan ke dalam variabel biodata
biodata = {"nama":"Andi", 'umur':21} #proses inisialisasi variabel biodata
print(biodata) #proses pencetakan variabel biodata yang berisi tipe data Dictionary
print(type(biodata)) #fungsi untuk mengecek jenis tipe data. akan tampil <class 'dict'> yang berarti dict adalah tipe data dictionary
# Out:
# True
# Ayo belajar Python
# Belajar Python Sangat Mudah
# 20
# 3.14
# 5j
# [1, 2, 3, 4, 5]
# ['satu', 'dua', 'tiga']
# (1, 2, 3, 4, 5)
# ('satu', 'dua', 'tiga')
# {'nama': 'Budi', 'umur': 20}
# {'nama': 'Andi', 'umur': 21}
# <class 'dict'>

# %%
#Kondisi if adalah kondisi yang akan dieksekusi oleh program jika bernilai benar atau TRUE

nilai = 21

#jika kondisi benar/TRUE maka program akan mengeksekusi perintah dibawahnya
if(nilai > 20):
    print("tujuh lima Lebih Besar Dari Angka dua puluh") # Kondisi Benar, Dieksekusi

#jika kondisi salah/FALSE maka program tidak akan mengeksekusi perintah dibawahnya
if(nilai > 100):
    print("tujuh lima Lebih Besar Dari Angka Seratus") # Kondisi Salah, Maka tidak tereksekusi
# Out:
# tujuh lima Lebih Besar Dari Angka dua puluh

# %%
#Kondisi if else adalah jika kondisi bernilai TRUE maka akan dieksekusi pada if, tetapi jika bernilai FALSE maka akan dieksekusi kode pada else

nilai = 7
#Jika pernyataan pada if bernilai TRUE maka if akan dieksekusi, tetapi jika FALSE kode pada else yang akan dieksekusi.
if(nilai >= 7):
    print("Selamat Anda Lulus")
else:
    print("Maaf Anda Tidak Lulus")
# Out:
# Selamat Anda Lulus

# %%
#Contoh penggunaan kondisi elif

hari_ini = "Selasa"

if(hari_ini == "Senin"):
    print("Saya Puasa")
elif(hari_ini == "Selasa"):
    print("Saya Makan")
elif(hari_ini == "Rabu"):
    print("Saya Makan")
elif(hari_ini == "Kamis"):
    print("Saya Puasa")
elif(hari_ini == "Jumat"):
    print("Saya Makan")
elif(hari_ini == "Sabtu"):
    print("Saya Makan")
elif(hari_ini == "Minggu"):
    print("Saya Makan")
# Out:
# Saya Makan

# %%
# mendefinisikan fungsi menggunakan 'def'
def ini_fungsi(siapaNamanya):
  print(siapaNamanya + " belajar Bahasa Isyarat")


# memanggil fungsi
ini_fungsi('Udin Nganga')

# memanggil kembali fungsi dengan nilai parameter berbeda
ini_fungsi('Mamang Garox')

# lagi
ini_fungsi('Semua orang')
# Out:
# Udin Nganga belajar Bahasa Isyarat
# Mamang Garox belajar Bahasa Isyarat
# Semua orang belajar Bahasa Isyarat

# %%
# memanggil modul numpy

import numpy as np
a  = np.array([1,2,3])

# mencetak dimensi dan tipe data matriks a
print(a.shape)
print(a.dtype)
# Out:
# (3,)
# int64

# %%
# memanggil numpy dan matplotlib
import numpy
import matplotlib.pyplot as plt


# membuat distribusi normal dengan mean=5, stdev=1 dan jumlah data 100.000 
x = numpy.random.normal(5.0, 1.0, 100000)

# plotting dengan matplotlib
plt.hist(x, 100)
plt.show()

# %%
# Melakukan instalasi Rasterio
# !pip install rasterio
# Out:
# ...
#      |████████████████████████████████| 19.3 MB 1.3 MB/s
# ...

# %%
# Memanggil modul rasterio yang sudah terinstall
# Dari Matplotlib, cukup ambil modul `pyplot`, yang digunakan untuk memperbesar 
# hasil plotting dari Rasterio
import rasterio
from matplotlib import pyplot as plt

# Format COG (Cloud Optimised Geotiff), dipanggil dari OpenAerialMap
alamat_citra = 'https://previews.123rf.com/images/lesniewski/lesniewski1504/lesniewski150400045/39510002-%E3%82%B9%E3%83%A9%E3%83%90%E3%83%A4%E8%A1%8C%E6%94%BF%E5%9C%B0%E5%9B%B3.jpg'
citra = rasterio.open(alamat_citra)

# perbesar ukuran hasil plotting 
plt.rcParams["figure.figsize"] = (15,15)

# Panggil submodul show pada rasterio, kemudian gunakan untuk menampilkan citra
# untuk menampilkan koordinat, gunakan parameter "transform" pada modul tersebut
from rasterio.plot import show
show(citra.read(), transform=citra.transform)
# Out:
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
